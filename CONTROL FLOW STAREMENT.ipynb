# %% [markdown]
# # CONTROL FLOW STATEMENT

# %% [markdown]
# ### In Python programming, control flow is the order in which statements or blocks of code are executed at runtime.

# %% [markdown]
# ![WhatsApp Image 2024-03-18 at 4.39.20 PM.jpeg](attachment:f74c8d0e-6e20-4e87-b50c-dd7aa1b56a02.jpeg)

# %%
x=67
y=78
if x==y:
    print("true")
elif x>y:
    print("true")
else:
    print("false")
# Out:
# false

# %%
x=98
y=100
if x==y:
    print("true")
elif x<y:
    print("true")
else:
    print("false")
# Out:
# true

# %%
a=[1,2,3,4,5,6]
b=(1,2)
if b in a:
    print("true")
elif b not in a:
    print("false")
else:
    print("wrong")
# Out:
# false

# %%
x=int(input())
y=int(input())
a=x/y
if x / y:
    print(a)
else:
    print("false")
# Out:
#  90
#  18
# 5.0

# %%
x= int(input("first number:"))
y= int(input("second number:"))
z= input("operator use:")
a= x+y
if x + y:
    print(a)
else:
    print("false")
# Out:
# first number: 56
# second number: 34
# operator use: addition +
# 90

# %%
x= int(input("first number:"))
y= int(input("second number:"))
z= input("operator use:")
a= x/y
if x / y:
    print(a)
else:
    print("false")
# Out:
# first number: 89
# second number: 23
# operator use: division /
# 3.869565217391304

# %%
x= int(input("first number:"))
y= int(input("second number:"))
print("Which of the following operation do you want to perform:")
print("Addition +")
print("Subtraction -")
print("Multiplication *")
print("division /")
z=input("operator use (+,-,*,/):")
if z=='+':
    a = x + y
elif z=='-':
    a= x - y
elif z=='*':
    a= x*y
elif z=='/':
    a= x/y
else:
    x<y
print("R:",a)
# Out:
# first number: 2
# second number: 0
# Which of the following operation do you want to perform:
# Addition +
# Subtraction -
# Multiplication *
# division /
# operator use (+,-,*,/): /
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 16
#      14     a= x*y
#      15 elif z=='/':
# ---> 16     a= x/y
#      17 else:
#      18     x<y
#
# ZeroDivisionError: division by zero

# %%
x= int(input("first number:"))
y= int(input("second number:"))
print("Which of the following operation do you want to perform:")
print("Addition +")
print("Subtraction -")
print("Multiplication *")
print("division /")
z=input("operator use (+,-,*,/):")
if z=="+":
    a=x+y
else:
    a=x-y
print(a)
# Out:
# first number: 56
# second number: 45
# Which of the following operation do you want to perform:
# Addition +
# Subtraction -
# Multiplication *
# division /
# operator use (+,-,*,/): +
# 101

# %%
x= int(input("first number:"))
y= int(input("second number:"))
print("Which of the following operation do you want to perform:")
print("Addition +")
print("Subtraction -")
print("Multiplication *")
print("division /")
z=input("operator use (+,-,*,/):")
if z=='+':
    a = x + y
elif z=='-':
    a= x - y
elif z=='*':
    a= x*y
elif y==0  :
    a="not define"
elif z=='/':
    a= x/y
else:
    x<y
print("R:",a)
# Out:
# first number: 2
# second number: 0
# Which of the following operation do you want to perform:
# Addition +
# Subtraction -
# Multiplication *
# division /
# operator use (+,-,*,/): *
# R: 0

# %%
x= int(input("first number:"))
y= int(input("second number:"))
print("Which of the following operation do you want to perform:")
print("Addition +")
print("Subtraction -")
print("Multiplication *")
print("division /")
z=input("operator use (+,-,*,/):")
if z=='+':
    a = x + y
elif z=='-':
    a= x - y
elif z=='*':
    a= x*y
elif z=='/':
    if y==0:
        print("Not define")
    else:
        a= x/y
else:
    x<y
print("R:",a)
# Out:
# first number: 56
# second number: 28
# Which of the following operation do you want to perform:
# Addition +
# Subtraction -
# Multiplication *
# division /
# operator use (+,-,*,/): /
# R: 2.0

# %%
x=input("name:")
y=int(input("age:"))
z=input("citizen:")
a=input("eligible:")
if y>=18 and z=="indian":
    print("right")
else:
    print("wrong")
# Out:
# name: dgfd
# age: 56
# citizen: indian
# eligible: for vote
# right

# %%
age=int(input())
if age<18:
    print("Minor")
elif 18<=age<=65:
    print("Adult")
elif 65<=age<=100:
    print("Senior")
elif age>100:
    print("Invalid age")
else:
    print("wrong")
# Out:
#  101
# Invalid age

# %%
age=int(input())
if age<18:
    print("Minor")
elif 18<=age<=65:
    print("Adult")
elif 65<=age<=100:
    print("Senior")
elif age>100:
    print("Invalid age")
else:
    print("wrong")
# Out:
#  17
# Minor

# %%
age=int(input())
if age<18:
    print("Minor")
elif 18<=age<=65:
    print("Adult")
elif 65<=age<=100:
    print("Senior")
elif age>100:
    print("Invalid age")
else:
    print("wrong")
# Out:
#  12
# Minor

# %%
age=int(input())
if age>100:
    print("Invalid age")
elif age<18:
    print("Minor")
elif age>65:
    print("Senior")
elif age>18:
    if age<=65:
        print("Adult")
# Out:
#  12
# Minor

# %%
# create a program as to check the number is odd or even.
num=int(input())
if num %2==0:
    print("even")
else:
    print("odd")
# Out:
#  5
# odd

# %%
#create a program as take an input from user that the current temperature in the surrounding to run the program.
temp=int(input("enter the current temperature:"))
if temp<10:
    print("It's cold! Bundle up.")
elif 10<=temp<=19:
    print("IT's a bit cold. Wear a jecket.")
elif 20<=temp<=29:
    print("It's comfortable. Wear moderate clothing.")
elif temp>30:
    print("It's hot! Wear light clothing.")
# Out:
# enter the current temperature: 25
# It's comfortable. Wear moderate clothing.

# %%
# create a program in which take two input from user as day and age to run the program .
age=int(input("enter age:"))
day=input("enter day:")

if age<18:
    print("pay Rs.8")
elif age>18:
    if"saturday"!= day !="sunday" :
        print("pay Rs.12")
    else:
        print("pay Rs.15")
# Out:
# enter age: 13
# enter day: friday
# pay Rs.8

# %%
# create a program in which take two input from user as day and age to run the program .
age=int(input("enter age:"))
day=input("enter day:")
a="monday,tuesday,wednesday,thursday,friday"
if age<18:
    print("pay Rs.8")
elif age>18:
    if day in a :
        print("pay Rs.12")
    else:
        print("pay Rs.15")
# Out:
# enter age: 20
# enter day: sunday
# pay Rs.15

# %%
#create a program of mark of students in which the grade are given to the students.
num=int(input("enter a number:"))
if 90<=num<=100:
    print("A")
elif 80<=num<=89:
    print("B")
elif 70<=num<=79:
    print("C")
elif 60<=num<=69:
    print("D")
elif num<60:
    print("F")
# Out:
# enter a number: 70
# C

# %%
# create a program in which the number should be palindrome number.
num=input("enter a number:")
num1=num[::-1]
if num==num1:
    print("it is a palindrome number")
else:
    print("it is not a palindrome number")
# Out:
# enter a number: 4444444444
# it is a palindrome number

# %%
# create a program in which to check the number is prime. 
num=int(input("enter a number:"))
if num==2 :
    print("even prime")
elif num==3:
    print("prime number")
elif num%2==0 or num%3==0 :
    print("not prime")
else:
    print("prime number")
# Out:
# enter a number: 131
# prime number

# %%
# create a program in which to check the number is prime. 
num=int(input("enter a number:"))
if num==2 :
    print("even prime")
elif num==3:
    print("prime number")
elif num==1:
    print("neither prime nor composite number")    
elif num%2==0 or num%3==0 or num%7==0:
    print("not prime")    
else:
    print("prime number")
# Out:
# enter a number: 23
# prime number

# %%
#create a program in which take three input from user for use of different operators.
x=int(input())
y=int(input())
z=int(input())
if x<y<z:
    print("accending order")
elif x>y>z:
    print("decending order")
elif x==y<z:
    print("z is greater than x and y")
elif x>y==z:
    print("x is greater than y and z")
elif x==z<y:
    print("y is greater than x and z")
elif x>y<z:
    print("y is smaller than x and z")
elif y>x<z:
    print("x is smaller than y and z ")
elif x>z<y:
    print("z  is smaller than x and y")
# Out:
#  12
#  12
#  23
# z is greater than x and y

# %%
# Create a program in which  simulates a guessing game where the user tries to guess a secret word of three letter.
a=input("enter a word:")
b=('a','e','i','o','u')
c=('a','b','c','d','e','f','g','h','i','j','l','m','n','o','p','q','r','u','v','w','x','y','z')
if len(a)!=3:
    print("invalid letter")
elif a[0]  in c:
    print("first letter")
elif a[1]  in b:
    print("second letter")
elif a[2] != 's' and a[2] != 't':
    print("third letter")
else:
    print("letter")
# Out:
# enter a word: sep
# second letter

# %%
# Create a program in which  simulates a guessing game where the user tries to guess a secret word of three letter.
a=input("enter a word:")
b=['a','e','i','o','u']
c=['s','t']
if len(a)!=3:
    print("invalid letter")
elif a[2] != 's' or a[2] != 't' or a[2] not in b:
    print(a,  "the number is guess by the user is correct")
elif a[0]!='s'or a[0]!='t':
    print("user has guess wrong letter")
elif a[1] not in b:
    print("user has guess wrong vowel letter ")
else:
    print("the number is guess by the user is not correct")
# Out:
# enter a word: ssa
# ssa the number is guess by the user is correct

# %%
# Create a program in which  simulates a guessing game where the user tries to guess a secret word of three letter.
a=input("enter a word:")
b=('a','e','i','o','u')
c=('s','t')
if len(a)!=3:
    print("invalid letter")
elif a[0] in c and a[1] in b and a[2] not in c and a[2] not in b:
    print("the number guess by the user is correct.")
else:
    print("the number guess by the user is wrong.")
# Out:
# enter a word: ssa
# the number guess by the user is wrong.

# %%
num=input("enter a three digit number:")
a=int(num[0])
b=int(num[1])
c=int(num[2])
num1=int(num)
if num1==a**3+b**3+c**3:
    print("true")
else:
    print("false")
# Out:
# enter a three digit number: 153
# true
